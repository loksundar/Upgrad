# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("census+data.xlsx")

# %%
import pandas as pd
marks = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/VodvGKvJAaeNrG7kvOQV38aog/class-grades.csv')
marks = marks[~(marks.isna().sum(axis=1)==5)]
marks.isna().sum()
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64

# %%
import pandas as pd
customer = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/9B2ZPE1apMvqrLWx7p8ge9dqX/cust_dimen.csv')

customer['Cust_id'] =customer['Cust_id'].apply(lambda x:x[5:])#Type your code here
print(customer.head(10))
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS       1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER       2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE       3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER       4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE       5
# 5      MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE       6
# 6     DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE       7
# 7     NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE       8
# 8         CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE       9
# 9       CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS      10

# %%
import pandas as pd
rating = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/JPAqXRWexo7nybkQ7BjPLWVN/rating_final.csv')

rating_update =rating.drop_duplicates() #Type your code here

print(rating.shape)
print(rating_update.shape)
# Out:
# (1254, 5)
# (1149, 5)

# %%
df = pd.read_csv("tendulkar_ODI.csv")
df.head()
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# 4  Nottingham  20-Jul-90

# %%
def conv(x):
    try:
        return int(x)
    except:
        try:
            return int(x[:-1])
        except:
            return 0

# %%
df["Runs"] = df["Runs"].apply(conv)

# %%
df.Runs.plot.hist(bins=int(max(df.Runs)/10))

# %%
def conv(x):
    try:
        return int(x)
    except:
        return -1

# %%
df["4s"] = df["4s"].apply(conv)

# %%
df["4s"].value_counts()
# Out:
#  0     69
#  1     37
#  2     29
#  3     25
#  4     17
#  5     16
#  9     15
#  6     14
#  8     13
#  7     13
#  10    11
#  13     8
#  12     5
#  15     4
#  11     4
#  16     4
# -1      3
#  14     3
#  19     2
#  20     1
#  17     1
#  25     1
# Name: 4s, dtype: int64

# %%
df.Runs.plot()

# %%
df = pd.read_csv("popularity.csv")
df.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
df[" num_keywords"].mode()
# Out:
# 0    7.0
# Name:  num_keywords, dtype: float64

# %%
df[" shares"].mean()
# Out:
# 3395.3801836343455

# %%
df[" shares"].median()
# Out:
# 1400.0

# %%
df[" shares"].plot.box()

# %%
df[" shares"].max()
# Out:
# 843300

# %%
np.percentile(df[" shares"],78)
# Out:
# 3100.0

# %%
df[df[" shares"]<=3100].shape
# Out:
# (31024, 61)

# %%
df[df[" shares"]<3100].shape
# Out:
# (30718, 61)

# %%
print(np.percentile(df[" shares"],10))
print(np.percentile(df[" shares"],20))
# Out:
# 708.0
# 870.6000000000004

# %%
print(np.percentile(df[" shares"],70))
print(np.percentile(df[" shares"],80))
# Out:
# 2300.0
# 3400.0

# %%
df[" shares"].quantile([0.1,0.2,0.3,0.4])
# Out:
# 0.1     708.0
# 0.2     870.6
# 0.3    1000.0
# 0.4    1200.0
# Name:  shares, dtype: float64

# %%
dfx = df[df[" shares"]<=df[" shares"].quantile(0.95)]

# %%
dfx[" shares"].mean()
# Out:
# 2074.334386533202

# %%
dfx
# Out:
# (37663, 61)

# %%
dfx[" shares"].std()
# Out:
# 1871.8141388442016

# %%
dfx.shape[0]/df.shape[0]
# Out:
# 0.950030269397639

# %%
df = pd.read_csv("EDA_census.csv")
df.head()
# Out:
#       c1  c2  c3     c4     c5        c6          c7         c8         c9  \
# 0  C2308   0   0  INDIA  Total  All ages  1210854977  623270258  587584719
# 1  C2308   0   0  INDIA  Total       0-6   164515253   85752254   78762999
# 2  C2308   0   0  INDIA  Total         7    24826640   12903364   11923276
# 3  C2308   0   0  INDIA  Total         8    26968373   14061937   12906436
# 4  C2308   0   0  INDIA  Total         9    23424638   12214985   11209653
#
#          c10        c11        c12        c13        c14        c15
# 0  447216165  188506636  258709529  763638812  434763622  328875190
# 1  164515253   85752254   78762999          0          0          0
# 2    6748214    3388683    3359531   18078426    9514681    8563745
# 3    4131414    2013742    2117672   22836959   12048195   10788764
# 4    2491904    1198339    1293565   20932734   11016646    9916088

# %%
x = df[(df["c6"]=="20-24")&(df["c5"]=="Total")&(df["c4"]=="INDIA")]
x
# Out:
#        c1  c2  c3     c4     c5     c6         c7        c8        c9  \
# 15  C2308   0   0  INDIA  Total  20-24  111424222  57584693  53839529
#
#          c10      c11       c12       c13       c14       c15
# 15  18679492  6467026  12212466  92744730  51117667  41627063

# %%
x["c12"]/x["c9"]
# Out:
# 15    0.226831
# dtype: float64

# %%
x = df[(df["c4"]=="INDIA")&(df["c5"]=="Total")]
x
# Out:
#        c1  c2  c3     c4     c5              c6          c7         c8  \
# 0   C2308   0   0  INDIA  Total        All ages  1210854977  623270258
# 1   C2308   0   0  INDIA  Total             0-6   164515253   85752254
# 2   C2308   0   0  INDIA  Total               7    24826640   12903364
# 3   C2308   0   0  INDIA  Total               8    26968373   14061937
# 4   C2308   0   0  INDIA  Total               9    23424638   12214985
# 5   C2308   0   0  INDIA  Total              10    30552107   16089436
# 6   C2308   0   0  INDIA  Total              11    24740946   12962604
# 7   C2308   0   0  INDIA  Total              12    27877307   14637892
# 8   C2308   0   0  INDIA  Total              13    24280683   12563775
# 9   C2308   0   0  INDIA  Total              14    25258169   13165128
# 10  C2308   0   0  INDIA  Total              15    25899454   13739746
# 11  C2308   0   0  INDIA  Total              16    24592293   13027935
# ...

# %%
x["ans"] = x["c13"]/x["c7"]
# Out:
# <ipython-input-151-6435c26d7f33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["ans"] = x["c13"]/x["c7"]

# %%
x = x[["c6","ans"]]
x
# Out:
#                 c6       ans
# 0         All ages  0.630661
# 1              0-6  0.000000
# 2                7  0.728187
# 3                8  0.846805
# 4                9  0.893620
# 5               10  0.886931
# 6               11  0.919628
# 7               12  0.914212
# 8               13  0.925436
# 9               14  0.916828
# 10              15  0.899613
# 11              16  0.897834
# 12              17  0.903926
# 13              18  0.866659
# 14              19  0.876376
# 15           20-24  0.832357
# 16           25-29  0.776811
# 17           30-34  0.725384
# 18           35-39  0.672740
# 19           40-44  0.629934
# 20           45-49  0.597586
# 21           50-54  0.575657
# 22           55-59  0.548305
# 23           60-64  0.469265
# 24           65-69  0.439440
# 25           70-74  0.397745
# 26           75-79  0.419313
# 27             80+  0.389632
# 28  Age not stated  0.645594

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x["c6"],x["ans"])

# %%
x["ans"][:17].sum()
# Out:
# 13.715884396776016

# %%
df = pd.read_csv("EDA_Gold_Silver_prices.csv")
df.head()
# Out:
#     Month  SilverPrice  GoldPrice
# 0  Mar-97       186.48   12619.24
# 1  Apr-97       170.65   12338.59
# 2  May-97       170.44   12314.94
# 3  Jun-97       169.96   12202.78
# 4  Jul-97       155.80   11582.07

# %%
df.corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
df["Year"] = df["Month"].apply(lambda x:x[-2:])
df["Year"]
# Out:
# 0      97
# 1      97
# 2      97
# 3      97
# 4      97
#        ..
# 236    16
# 237    16
# 238    17
# 239    17
# 240    17
# Name: Year, Length: 241, dtype: object

# %%
x = df[df["Year"]=="08"]
x
# Out:
#       Month  SilverPrice  GoldPrice Year
# 130  Jan-08       632.29   35025.78   08
# 131  Feb-08       701.87   36642.46   08
# 132  Mar-08       775.49   39082.77   08
# 133  Apr-08       700.96   36416.00   08
# 134  May-08       718.20   37435.38   08
# 135  Jun-08       729.63   38087.88   08
# 136  Jul-08       773.80   40256.56   08
# 137  Aug-08       625.97   36026.85   08
# 138  Sep-08       555.58   37815.02   08
# 139  Oct-08       507.20   39235.79   08
# 140  Nov-08       483.55   37284.82   08
# 141  Dec-08       501.82   39696.27   08

# %%
x.corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.009584
# GoldPrice       0.009584   1.000000

# %%
plt.plot(df["SilverPrice"],df["GoldPrice"])

# %%
df = pd.read_csv("currencies.csv")
df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula  ...  South African Rand  Sri Lanka Rupee  Swedish Krona  \
# ...

# %%
import matplotlib.pyplot as plt

plt.matshow(df.corr())
plt.show()

# %%
df[["Indian Rupee","Australian Dollar","U.S. Dollar","Euro","Japanese Yen"]].corr()
# Out:
#                    Indian Rupee  Australian Dollar  U.S. Dollar      Euro  \
# Indian Rupee           1.000000           0.921475     0.872862  0.243851
# Australian Dollar      0.921475           1.000000     0.607010  0.331588
# U.S. Dollar            0.872862           0.607010     1.000000 -0.210587
# Euro                   0.243851           0.331588    -0.210587  1.000000
# Japanese Yen          -0.270123          -0.582032     0.210295 -0.645719
#
#                    Japanese Yen
# Indian Rupee          -0.270123
# Australian Dollar     -0.582032
# U.S. Dollar            0.210295
# Euro                  -0.645719
# Japanese Yen           1.000000

# %%
df[["Indian Rupee","Australian Dollar","U.S. Dollar","Euro","Japanese Yen","Chinese Yuan","U.K. Pound Sterling"]].corr()
# Out:
#                      Indian Rupee  Australian Dollar  U.S. Dollar      Euro  \
# Indian Rupee             1.000000           0.921475     0.872862  0.243851
# Australian Dollar        0.921475           1.000000     0.607010  0.331588
# U.S. Dollar              0.872862           0.607010     1.000000 -0.210587
# Euro                     0.243851           0.331588    -0.210587  1.000000
# Japanese Yen            -0.270123          -0.582032     0.210295 -0.645719
# Chinese Yuan             0.304050           0.077983     0.291582  0.151596
# U.K. Pound Sterling      0.314681           0.579213    -0.042303  0.531150
#
#                      Japanese Yen  Chinese Yuan  U.K. Pound Sterling
# Indian Rupee            -0.270123      0.304050             0.314681
# Australian Dollar       -0.582032      0.077983             0.579213
# U.S. Dollar              0.210295      0.291582            -0.042303
# Euro                    -0.645719      0.151596             0.531150
# ...

# %%
df =pd.read_csv("nas.csv")
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
df = df[["Siblings",'Mother.edu']]
df
# Out:
#         Siblings    Mother.edu
# 0      1 sibling    Illiterate
# 1     3 siblings    Illiterate
# 2     3 siblings    Illiterate
# 3     3 siblings     Secondary
# 4     2 siblings    Illiterate
# ...          ...           ...
# 8796   1 sibling     Secondary
# 8797  2 siblings     Secondary
# 8798   1 sibling     Secondary
# 8799   1 sibling  Sr secondary
# 8800   1 sibling     Secondary
#
# [8801 rows x 2 columns]

# %%
df = df[df['Mother.edu']=="Illiterate"]

# %%
df.groupby("Siblings").count()
# Out:
#               Mother.edu
# Siblings
# 1 sibling            533
# 2 siblings           923
# 3 siblings           532
# 4+ siblings          469
# Single child          88

# %%
df = pd.read_csv("odi-batting.csv")
df
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82  10-07-2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57  01-07-2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5  10-03-1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3  03-02-1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls
# 0         Sharjah CA Stadium        Canada    121
# 1                 VRA Ground   Netherlands    111
# ...

# %%
df["century"] = np.where(df["Runs"]>=100,1,0)
df
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82  10-07-2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57  01-07-2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5  10-03-1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3  03-02-1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls  century
# 0         Sharjah CA Stadium        Canada    121        1
# ...

# %%
df.groupby("Player").sum().sort_values(by = "century")
# Out:
#                       Runs  Balls  century
# Player
# Aamer Hanif             89    128        0
# Nathan W Bracken       198    266        0
# Nathan M Hauritz       336    348        0
# Nathan L McCullum      450    542        0
# Nasir Javed              2     19        0
# ...                    ...    ...      ...
# Herschelle H Gibbs    8094   9645       21
# Sourav C Ganguly     11363  15350       22
# Sanath T Jayasuriya  13430  14639       28
# Ricky T Ponting      13686  16947       30
# Sachin R Tendulkar   18111  20894       48
#
# [1883 rows x 3 columns]

# %%
df["sr"] = df["Runs"]/df["Balls"]

# %%
dfx = df[df["Runs"]>=100]

# %%
dfx.sort_values("sr",ascending=False)
# Out:
#             Country                     Player  Runs   MatchDate Weekday  \
# 28157      Pakistan              Shahid Afridi   102  04-10-1996     Fri
# 28158      Pakistan              Shahid Afridi   102  15-04-2005     Fri
# 34446  South Africa             Mark V Boucher   147  20-09-2006     Wed
# 28153      Pakistan              Shahid Afridi   124  21-06-2010     Mon
# 36753     Sri Lanka        Sanath T Jayasuriya   134  02-04-1996     Tue
# ...             ...                        ...   ...         ...     ...
# 28851      Pakistan                 Ramiz Raja   102  23-02-1992     Sun
# 24821   New Zealand             Glenn M Turner   114  14-06-1975     Sat
# 43594   West Indies  Cuthbert Gordon Greenidge   103  21-11-1981     Sat
# 43591   West Indies  Cuthbert Gordon Greenidge   106  09-06-1979     Sat
# 2141      Australia               David C Boon   102  10-12-1991     Tue
#
#                                      Ground       Versus  Balls  century  \
# ...

# %%
df = df[df["Country"]=="India"]
df
# Out:
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
# 13602   India  Sachin R Tendulkar   186  08-11-1999     Mon
# 13603   India  Sachin R Tendulkar   175  05-11-2009     Thu
# 13604   India  Sachin R Tendulkar   163  08-03-2009     Sun
# 13605   India  Sachin R Tendulkar   152  23-02-2003     Sun
# ...       ...                 ...   ...         ...     ...
# 19645   India     Rajinder S Ghai     1  26-01-1986     Sun
# 19646   India     Nandlal S Yadav     1  09-02-1986     Sun
# 19647   India        Naman V Ojha     1  05-06-2010     Sat
# 19648   India        Sudeep Tyagi     1  27-02-2010     Sat
# 19649   India        Yograj Singh     1  14-02-1981     Sat
#
#                                    Ground        Versus  Balls  century  \
# 13601          Captain Roop Singh Stadium  South Africa    147        1
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150        1
# ...

# %%
df["MatchDate"] = pd.to_datetime(df["MatchDate"],format = "DD/MM/YYYY")
# Out:
# <ipython-input-234-3c3165abf89d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MatchDate"] = pd.to_datetime(df["MatchDate"],format = "DD/MM/YYYY")

# %%
df["Year"] = df["MatchDate"].apply(lambda x:x.year)
# Out:
# <ipython-input-235-574c68eb9621>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] = df["MatchDate"].apply(lambda x:x.year)

# %%
df.groupby("Year").sum()
# Out:
#       Runs  Balls  century          sr
# Year
# 1974   414    593        0   12.395630
# 1975   458    914        0    9.767943
# 1976   299    535        0   11.036657
# 1978   404    670        0   10.874886
# 1979   519    959        0   18.869968
# 1980   911   1465        0   27.213236
# 1981  1305   2256        0   43.732055
# 1982  1870   2364        0   51.502834
# 1983  3526   5317        1  102.924128
# 1984  1777   2577        3   49.487248
# 1985  2544   3687        0   72.967883
# 1986  4799   7198        2  139.409280
# 1987  4327   5644        4  121.007165
# 1988  3979   5453        5  114.047803
# 1989  3028   4478        2  113.703920
# 1990  2458   3560        3   70.340027
# 1991  2658   3990        2   65.358202
# 1992  3657   5689        1  122.672438
# 1993  3440   4800        2   95.638121
# 1994  4986   6489        7  127.679969
# 1995  2246   3015        1   59.893345
# 1996  6422   8749        8  189.394181
# 1997  7138   9822        7  208.012635
# ...

# %%
df = pd.read_csv("grades.csv")
df
# Out:
#                                             submission        submit_time
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# ..                                                 ...                ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b...  01/03/17-22:43:12
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44...  01/09/17-23:59:34
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a...  12/19/16-21:44:13
# 196  https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4a...  01/09/17-23:23:06
# 197  https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a...  01/03/17-22:32:38
#
# [198 rows x 2 columns]

# %%
df["submission"][0]
# Out:
# 'https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip'

# %%
df["date"] = pd.to_datetime(df["submit_time"])

# %%
df["day"] = df["date"].apply(lambda x:x.day)
df["month"] = df["date"].apply(lambda x:x.month)
df["year"] = df["date"].apply(lambda x:x.year)

# %%
df["hour"] = df["date"].apply(lambda x:x.hour)
df["minute"] = df["date"].apply(lambda x:x.minute)

# %%
df
# Out:
#                                             submission        submit_time  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# ..                                                 ...                ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b...  01/03/17-22:43:12
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44...  01/09/17-23:59:34
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a...  12/19/16-21:44:13
# 196  https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4a...  01/09/17-23:23:06
# 197  https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a...  01/03/17-22:32:38
#
#                    date  day  month  year  hour  minute
# ...

# %%
df["format"] = df["submission"].apply(lambda x:x.split(".")[-1])

# %%
df
# Out:
#                                             submission        submit_time  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# ..                                                 ...                ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b...  01/03/17-22:43:12
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44...  01/09/17-23:59:34
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a...  12/19/16-21:44:13
# 196  https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4a...  01/09/17-23:23:06
# 197  https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a...  01/03/17-22:32:38
#
#                    date  day  month  year  hour  minute format
# ...

# %%
df["format"].value_counts()/df.shape[0]
# Out:
# zip    0.954545
# R      0.035354
# 7z     0.010101
# Name: format, dtype: float64

# %%
fdl= pd.to_datetime("2017-01-03-11:59:59")
fdl
# Out:
# Timestamp('2017-01-03 11:59:59')

# %%
fdl.month
# Out:
# 1

# %%
df["fdl"] = np.where(df["date"]>fdl,1,0)

# %%
df["fdl"].value_counts()
# Out:
# 1    156
# 0     42
# Name: fdl, dtype: int64

# %%
fdl= pd.to_datetime("2017-01-09-11:59:59")
fdl
# Out:
# Timestamp('2017-01-09 11:59:59')

# %%
df["date"] = df["date"].apply(lambda x:x.date())

# %%
df["date"].value_counts()
# Out:
# 2017-01-03    120
# 2017-01-09     21
# 2017-01-02     14
# 2017-01-04     12
# 2016-12-30      6
# 2017-01-01      6
# 2017-01-08      3
# 2017-01-10      3
# 2016-12-29      2
# 2016-12-28      2
# 2017-01-07      2
# 2017-01-17      1
# 2017-02-03      1
# 2016-12-21      1
# 2017-01-06      1
# 2016-11-19      1
# 2016-12-31      1
# 2016-12-19      1
# Name: date, dtype: int64

# %%
df["date"][0].date()
# Out:
# datetime.date(2017, 1, 3)

# %%
plt.plot(df["hour"].value_counts())

# %%
df[""]
